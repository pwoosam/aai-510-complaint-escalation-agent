# %% [markdown]
# ## Install dependencies and restart python

# %%
# %pip install -U -qqqq backoff databricks-openai uv databricks-agents mlflow-skinny[databricks] databricks-langchain openpyxl
dbutils.library.restartPython()
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import mlflow
import pandas as pd

experiment_name = "evaluation_test_cases_judge2"
df = mlflow.search_traces(
    locations=[mlflow.get_experiment_by_name(f"/Shared/{experiment_name}").experiment_id],
)
df.to_excel(f'./mlflow_traces/{experiment_name}.xlsx', sheet_name='traces', index=False)
